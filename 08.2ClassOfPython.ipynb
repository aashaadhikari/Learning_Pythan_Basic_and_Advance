# %% [markdown]
# # Python Classes and Objects
# A class in Python is a template for creating objects. It groups data (attributes) and functions (methods) together.
# Classes are defined using the `class` keyword, and attributes are accessed with the `dot (.)` operator.

# %% [markdown]
# In Python, **everything is an object** because Python is designed with a consistent and flexible **object-oriented model**.
#
# ### Here's why:
#
# * **All data types** (int, float, string, list, etc.) are **classes**, and their values are **objects** of those classes.
# * Even **functions**, **modules**, and **classes themselves** are objects.
# * Objects in Python have **attributes** and **methods**, which makes them flexible and powerful.

# %% [markdown]
# # create a class

# %%
# define a class
class Dog:
    sound = 'bark'

# %% [markdown]
# # Create Object
# An Object is an instance of a Class. It represents a specific implementation of the class and holds its own data.

# %%
class Dog:
    sound = 'bark'

# Create an object from the class
dog1 = Dog()

# Access the class attribute
print(dog1.sound)
# Out:
# bark

# %% [markdown]
# # Using __init__() Function
# In Python, class has __init__() function. It automatically initializes object attributes when an object is created.

# %%
class Dog:
    species = "Canine" # class attribute

    def __init__(self, name, age):
        self.name = name
        self.age = age

# %%
class Car:
    def __init__(self, color, model):
        self.color = color
        self.model = model

    def honk(self):
        print("Beep Beep!")

my_car = Car('Red', "Toyota")
my_car.honk()
# Out:
# Beep Beep!

# %% [markdown]
# # Self Parameter
# self parameter is a reference to the current instance of the class. It allows us to access the attributes and methods of the object.

# %%
class Dog:
    def __init__(self, name, age):  
        self.name = name 
        self.age = age

    def bark(self): 
        print(f"{self.name} is barking!")

# Creating an instance of Dog
dog1 = Dog("Buddy", 3)
dog1.bark()
# Out:
# Buddy is barking!

# %% [markdown]
# # __str__ Method
#  __str__ method in Python allows us to define a custom string representation of an object. By default, when we print an object or convert it to a string using str(), Python uses the default implementation
