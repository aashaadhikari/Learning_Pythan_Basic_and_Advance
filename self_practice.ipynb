# %%
class list1:
    my_list = []
    my_list.append(["apple", "banana"])
    my_list.append(["cricket", "football"])
    print(my_list)
# Out:
# [['apple', 'banana'], ['cricket', 'football']]

# %%
def add(a, b):
    sume = a+b
    return print(sume)

# %%
va=add(2,3)
print(va)
# Out:
# 5
# None

# %%
def add(a,b):
    sume = a + b
    return sume

# %%
cat=add(2,6)
print(cat)
# Out:
# 8

# %%
def add(a, b):
    return  a+b
va = add(2,3)
print(va)
# Out:
# 5

# %%
#print(my_list[0])
for item in my_list[1]:
    print(item)
# Out:
# cricket
# football

# %%
a = 2
a-=1
print(a)
# Out:
# 1

# %%
class fruit:
    def __init__(self):
        self.dis = {
            "apple": 2, 
            "banana": 3
            }

    def fout(self):
        for key in self.dis:
            print(list(self.dis.keys())[1])

# %%
falful = fruit()
falful.fout()
# Out:
# banana
# banana

# %% [markdown]
# #  validate user input exersise
# 1. user is not more then 12 character
# 2. username must not conten space
# 3. username must not contain digits

# %%
username = input("Enter the username: ")

if len(username) > 12:
    print("username can't be more then 12 character")

elif not username.find(" ") == -1:
    print("your username can't content space")

elif not username.isalpha():
    print("digit is not avaialable")
else:
    print(username)
# Out:
# Enter the username:  kjhgf
# kjhgf

# %% [markdown]
# #  python compound intrest calculator

# %%
def chai(n):
    print(n)

chai(4)
# Out:
# 4

# %%
chai("seema is learning again basic")
# Out:
# seema is learning again basic

# %%
chai(1234)
# Out:
# 1234
