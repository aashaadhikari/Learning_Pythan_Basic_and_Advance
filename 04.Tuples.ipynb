# %% [markdown]
# # Python Tuples
# A tuple in Python is an ordered and immutable collection.
# Unlike lists, tuples cannot be changed after creation.
# They can store different data types and keep the order of elements.
#
# ## Creating a Tuple
# A tuple is created by placing all the items inside parentheses (), separated by commas. A tuple can have any number of items and they can be of different data types.
#
# ### Example

# %%
# creating an empty Tuple
tup =()
print(tup)

# Using string
tup = ("aasha", "for")
print(tup)

# Using List
tup = tuple("aasha")
print(tup)
# Out:
# ()
# ('aasha', 'for')
# ('a', 'a', 's', 'h', 'a')

# %% [markdown]
# ## Creating a Tuple with Mixed Datatypes
# Tuples can contain elements of various data types, including other tuples, lists, dictionaries and even functions.
#
# ### Example

# %%
# Creating a Tuple with Mixed DataType 
tup = (5, "welcome", 6, 'aasha')
print(tup)

#creating a Tuple with nested tuples
tup1 =(0,1,2,3)
tup2=('python', 'aasha')
tup3 = (tup1, tup2)
print(tup3)

# Creating a Tuple with repetition
tup1 = ("geeks",) * 3
print(tup1)

# Creating a Tuple with the use of loop
tup = ('geeks')
n=5
for i in range(int(n)):
    tup = (tup,)
    print(tup)
# Out:
# (5, 'welcome', 6, 'aasha')
# ((0, 1, 2, 3), ('python', 'aasha'))
# ('geeks', 'geeks', 'geeks')
# ('geeks',)
# (('geeks',),)
# ((('geeks',),),)
# (((('geeks',),),),)
# ((((('geeks',),),),),)

# %% [markdown]
# # Python Tuple Basic Operations
# Below are the Python tuple operations.
# * Accessing of Python Tuples
# * Concatenation of Tuples
# * Slicing of Tuple
# * Deleting a Tuple
#
# ##
