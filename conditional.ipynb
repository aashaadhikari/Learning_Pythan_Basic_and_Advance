# %% [markdown]
# # Conditional Statements
#
# ## Overview
# ### Notes
# `if`, `elif`, and `else` are conditional statements that control the flow of execution based on whether a condition is `True` or `False`.
#
# if - First condition check
#
# elif - subsequent condition check
#
# else - Fallback if no conditions are met

# %% [markdown]
# Heere is an example of how to use `if` statement in python:

# %%
x = 55
if x> 0:
    print("Inside if Block")
print(f"Given Number is {x}")
# Out:
# Inside if Block
# Given Number is 55

# %%
if x != 0:
    print("out of block")
# Out:
# out of block

# %% [markdown]
# Multiple conditions can be checked in an `if` statement by using logical operators like `and` and `or`.
#
# Here is an example:

# %%
x = 5
y =-5
if x>0 and y>0:
    print("Both x and y are positive")

# %% [markdown]
# Here's another example that if the first condition is `False`. Then let's do something `else`.

# %%
if False:
    print("hey Data Nerd")
else:
    print("what's up data Nerd")
# Out:
# what's up data Nerd

# %%
n = int(input("Enter the number: "))

if (n%2 == 0):
    print ("Even")

else:
    print("what you are thinking find even one")
# Out:
# Enter the number:  4
# Even

# %% [markdown]
# # If
#
# `if`: Evaluates a condition. If the condition is true, the block of code under the if statement executes. If the condition is false, it skips this block.
#
# # Example
# Let's see if our skill matches with a jobs required skills. We'll use one variable to represent the applicant's skill and another to represent the skill required for the job. Then we compare these variables using an if statement, to determine if the desired job matches the available job posting.

# %%
application_skill = "SQL"
job_skill = "SQL"
result = "No skill Match"

# %% [markdown]
# 🪲 Debugging
#
# This is an intentional mistake
#
# This is used to demonstrate debugging.
#
# Error: Using the wrong opertor = for a checking a condition
#
# `if applicant_skill = job_skill:`
#
# Steps to Debug:
#
# 1. Look at the actual error, can you tell what the problem is?
# 2. If not, then look it up paste in a Chatbot like ChatGPT or Claude

# %%
if application_skill = job_skill:
  result ="skill Match"
result
# Out:
#   Cell In[10], line 1
#     if application_skill = job_skill:
#        ^
# SyntaxError: invalid syntax. Maybe you meant '==' or ':=' instead of '='?

# %% [markdown]
# The corret is bellow:

# %%
if application_skill == job_skill:
   result ="skill Match"
    
result
# Out:
# 'skill Match'

# %% [markdown]
# # Elif
# ## Notes
#  * `Elif`: Follows an if or another elif statement. It's saying "if the previous conditions were not true, then try this condition". Or if the elif condition is true, its block executes.
#
# # Example

# %%
years_experience = 4

# %%
if application_skill == job_skill and years_experience < 2:
    result = "Junior DAP"

elif application_skill == job_skill and years_experience <= 5:
     result ="mid DAP"

else:
    result= "senior DAP" 

result
# Out:
# 'mid DAP'

# %% [markdown]
# # Else
# ## Notes
# `Else` runs if anything before it doesn't run.

# %% [markdown]
# # Pass
# ## Notes
#  * If statements can't be empty, but if you have an `if` statement with nothing in it, you can use `pass` to avoid getting an error.
#
# # Example
# * We create an if statement
# * Use pass within the statement, so it doesn't run an error

# %%
if application_skill == job_skill
# Out:
#   Cell In[20], line 1
#     if application_skill == job_skill
#                                      ^
# SyntaxError: expected ':'

# %%
LogdIn = False

print("I am here")

if (LogdIn):
    print("Welcome Back")
    print("Hello python is awesome ")

else:
    print("please login")
    print("still share this series")

print("i am out")
# Out:
# I am here
# please login
# still share this series
# i am out

# %%
n = int(input("enter the number: "))

if(n < 10):
    print("given number is lessthen 10")

else:
    print("put another one")
# Out:
# enter the number:  e
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 n = int(input("enter the number: "))
#       3 if(n < 10):
#       4     print("given number is lessthen 10")
#
# ValueError: invalid literal for int() with base 10: 'e'

# %%
charn = int(input("enter the number: "))

print(charn)
# Out:
# enter the number:  e
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 charn = int(input("enter the number: "))
#       3 print(charn)
#
# ValueError: invalid literal for int() with base 10: 'e'

# %%
charInp = input("enter a character")

print(charInp)
# Out:
# enter a character r
# r

# %% [markdown]
# # Correct syntax

# %%
if application_skill == job_skill:
    pass

# %% [markdown]
# # Nested if___ condition

# %%
x = 20
if x > 0:
    print(f"Given number {x} is positive")

elif x == 0:
      print(f"Given number {x} is zero")

# %% [markdown]
# # Example

# %%
hungry = True

money = 1000

order = True

# %%
if(hungry):
    if(money == 0):
        print("just sleep")

    elif (money > 1000):
        print("let's have party")

    elif(money > 100 and money <500):
        print("have some thing great")
        if(order):
            print("you can order")

        else:
            print("no need to eat")

    else:
        print("Order in")

else:
    print("we won't eat")
# Out:
# Order in

# %% [markdown]
# We will be taken a input from the user, first we will check if its a character (a-z, A-Z, 0-1) and then what is it

# %%
ch= input("Enter the cha")

# %%
if(ch >= 'a' and ch <='z' or ch >= 'A' and ch <=' Z' or ch >= '0' and ch < '9'):
    print("True")

else:
    print("dfghjkl")
# Out:
# True

# %% [markdown]
# # Question for Conditional

# %% [markdown]
# 1. Implement check_loan-eligibility code that determines person's loan eligibility on bellow condition.
#
# - The person should be at least 18 years old
# - if income is get 30000 or more
#       - credit score 700+ prime loan
#       - credit score 600-699 standard loan
#       - credit score below 600 high range loan
#
# - if income less then 20000 not eligible

# %%
person = (input("enter the name of person"))
Age = int(input("enter the age of person"))
salary = int(input("Enter the salary of person"))
CreditScore = int(input("Enter the CreditScore"))
# Out:
# enter the name of person aasha
# enter the age of person 17
# Enter the salary of person 35000
# Enter the CreditScore 700

# %%
if (Age >= 18):
    if(salary >= 30000 ):
        if(CreditScore > 700):
            print(f"{person} will get Prime Loan")

        elif(CreditScore >= 600 and CreditScore <= 699):
            print(f"{person} will get Standard Loan")

        elif(CreditScore < 600):
            print(f"{person} will get High_risk Loan")

    else:
        print("Not Eligible")
        

else:
    print("Not Eligible")
# Out:
# Not Eligible

# %% [markdown]
# # Write a program to check if an year is leap year or not

# %%
year = int(input("Enter the year"))

if (year% 4 == 0):
    if(year % 100 == 0):
        if(year % 400==0):
            print ("it is leap year")

        else:
            print("it is not leap year")

    else:
        print("it is leap year")

else:
    print("it is not leap year")
# Out:
# Enter the year 2024
# it is not leap year

# %%
year = int(input("Enter the year: "))

if (year % 400 == 0):
    print("It is a leap year")
elif (year % 100 == 0):
    print("It is not a leap year")
elif (year % 4 == 0):
    print("It is a leap year")
else:
    print("It is not a leap year")
# Out:
# Enter the year:  2024
# It is a leap year

# %% [markdown]
# # Python Conditionals Practice
#
# This notebook contains 10 questions on conditionals in Python, arranged in increasing order of difficulty. Each question is followed by a code cell where you can write your solution. Good luck!

# %% [markdown]
# ## Question 1: Even or Odd
#
# Write code that takes a number as input and prints whether it's even or odd.

# %%
number = int(input("Enter the number"))

if(number == 0):
    print("Nither even nor odd")

elif(number % 2 == 0):
    print("Even")

else:
    print("Odd")
# Out:
# Enter the number 0
# Nor even nor odd

# %% [markdown]
# ## Question 2: Positive, Negative, or Zero
#
# Write code that takes a number as input and prints whether it's positive, negative, or zero.

# %%
number = int(input("Enter the number"))

if (number > 0):
    print("Posative Value")

elif (number < 0):
    print("Negative Value")

else:
    print("It is Zero Value")
# Out:
# Enter the number 0
# It is Zero Value

# %% [markdown]
# ## Question 3: Grading System
#
# Write code that takes a student's score (0-100) as input and prints their grade according to the following scale:
# - A: 90-100
# - B: 80-89
# - C: 70-79
# - D: 60-69
# - F: Below 60

# %%
number = int(input("Enter the marks of student"))

if(number >= 90 and number < 100):
    print("Grade A")

elif(number >= 80 and number < 90):
    print("Grade B")

elif(number >= 70 and number < 80):
    print("Grade C")

elif(number >= 60 and number < 70):
    print("Grade D")

else:
    print("Grade F")
# Out:
# Enter the marks of student 60
# Grade D

# %% [markdown]
# ## Question 4: Leap Year Checker
#
# Write code that takes a year as input and prints whether it's a leap year or not. A leap year is divisible by 4, except for century years, which must be divisible by 400 to be a leap year.

# %%
year = int(input("Enter the year"))

if(year % 4 == 0):
    if(year % 100 == 0 ):
        if(year % 400 == 0):
            print("this is a leap Year")

        else:
            print("not a leap year")

    else:
        print("its a leap year")

else:
    print("not a leap year")
# Out:
# Enter the year 2058
# not a leap year

# %% [markdown]
# ## Question 5: Triangle Type
#
# Write code that takes the lengths of three sides of a triangle as input and prints whether it's equilateral (all sides equal), isosceles (two sides equal), or scalene (no sides equal).

# %%
a, b, c = map(int, input("Enter all three value"))

print(a, b, c)

if(a == b == c):
    print("Equilateral")

elif(a == b or b == c or a == c):
    print("isosceles")

elif(a != b != c):
    print("Scalene")
# Out:
# Enter all three value 122
# 1 2 2
# isosceles

# %% [markdown]
# ## Question 6: Rock, Paper, Scissors
#
# Write code for a simple Rock, Paper, Scissors game. Take inputs from two players and determine the winner based on the rules: Rock beats Scissors, Scissors beats Paper, and Paper beats Rock.

# %%
import random as 

my_list = ["Rock", "Paper", "Scissors"]

player1 = random.choice(my_list)

player2 = random.choice(my_list)

print("player one chose", player1)
print("Player two chose", player2)

if(player1 == player2):
    print("Draw")

elif(player1 == "scissors" and player2 == "Paper"):
    print("player 1 win")

elif(player1 == "Rock" and player2 == "Scissors"):
    print("player 1 win")

elif(player1 == "paper" and player2 == "Rock"):
    print("player 1 win")

else:
    print("player2 won!")
# Out:
# player one chose Scissors
# Player two chose Scissors
# Draw

# %% [markdown]
# ## Question 7: Days in a Month
#
# Write code that takes a month (as a number 1-12) and a year as input, then prints the number of days in that month. Remember to account for leap years affecting February.

# %%
month = int(input("Enter the month in numeric(1-12)"))
year = int(input("Enter the year"))

def is_leap_year(year):
    if ((year % 400 == 0) or(year % 4 ==0 and year % 100 !=0)):
        return True

    return False

if month in [1,3,5,7,8,10,12]:
    days=31

elif month in [4,6,9,11]:
    days = 30

elif month == 2:
    if is_leap_year(year):
        days = 29

    else:
        days = 28

else:
    print("Invalide")

print(f"the days is", {days})
# Out:
# Enter the month in numeric(1-12) 1
# Enter the year 2019
# the days is {31}

# %% [markdown]
# ## Question 8: Quadratic Equation Solver
#
# Write code that solves a quadratic equation. Take coefficients a, b, and c as input and print the roots. Handle all cases: two distinct real roots, one real root (double root), and complex roots.

# %% [markdown]
# ## Question 9: Tax Calculator
#
# Write code for a simple tax calculator. Take annual income as input and calculate tax based on the following brackets:
# - Up to $10,000: 0%
# - $10,001 to $50,000: 10%
# - $50,001 to $100,000: 20%
# - Above $100,000: 30%
#
# Print both the tax amount and the net income after tax.

# %% [markdown]
# ## Question 10: Credit Card Validator
#
# Write code that implements the Luhn algorithm to validate a credit card number. Take a credit card number as input (as a string) and print whether it's valid or not. The Luhn algorithm works as follows:
# 1. Double every second digit from right to left. If doubling results in a two-digit number, add up those digits.
# 2. Add all the untouched digits and the doubled digits.
# 3. The total should be a multiple of 10 for the card to be valid.
